# %%
#1. - Filename complete
#2. *** CREATE A LIST OF AT LEAST 5 ELEMENTS ***

#List containing Name, Age, Street Address, Vehicle Make, and Ownership of pet
profile = ["Jonathan", 29, 3836, "Ford", True]

profile[0]="Jim"

profile.append("Cheesecake") #Favorite dessert added to index 5.
profile.insert(3, "15734") #Zipcode added

print(len(profile), "elements in list.")

profile2 = profile[4:7] #slicing first list and saved as different 2nd list
print(profile2)  #printing 2nd list

profile.extend(profile2)  #extend original list with 2nd list sliced above

simList = [True, False, True, False, True]
simList.sort(reverse=False)
print(simList)

ThirdList = simList  #copying simList to another 3rd list

FourthList = ThirdList + profile2

print(FourthList)

#3. ***CREATE A TUPLE OF ABOUT 5 ELEMENTS***

skipCountby5 = (0, 5, 10, 15, 20)
skipCountrepeated = skipCountby5 * 3
print(skipCountrepeated[11])

sortedSCR = tuple(sorted(skipCountrepeated))  #Sort the second tuple
print(sortedSCR)                              #and print it

ThirdTuple = sortedSCR[3:13:3]  #Copy 4 specific elements from you 2nd tuple to the new 3rd tuple
print(ThirdTuple)

Index0 = ThirdTuple[0]   #unpacke the 3rd tuple into 4 variable
Index1 = ThirdTuple[1]
Index2 = ThirdTuple[2]
Index3 = ThirdTuple[3]

print(Index0, Index1, Index2, Index3)  #print these variables

FourthTuple=(50, )   #create a 4th tuple with single item 50
print(FourthTuple)   #and print this tuple

FifthTuple = sortedSCR+ThirdTuple  #add the 2nd and 3rd tuple together into a 5th tuple and print the tuple
print(FifthTuple)

#4 ***CREATE A SET OF ABOUT 5 ELEMENTS***
fruits = {"apple", "banana", "grape"}
print(fruits)
fruits.add("Ford")

oddities = {"fork", "stringcheese", "leaves"}   #create a 2nd set with a few odd items

ThirdSet = fruits.union(oddities)  #save the union of 1st set and 2nd set to a 3rd set

oddities.pop()  #pop an element from the 2nd set, print remainder of set
print(oddities)

#CREATE A DICTIONARY WITH AT LEAST 5 VALUES OF DIFFERENT DATA TYPES

FirstDict = {'1':"Blue", '2':"Green", '3': "Orange", '4': "Red", '5':"Purple"} 

FirstDict.update({'2':"Jonathan"}) #replace any one value with your name

FirstDict['6']="Navy"  #add your favorite color to the dictionary

FirstDict['7'] = oddities #add a set to your dictionary

print(FirstDict.keys())  #print a list of the dictionary keys

print(FirstDict.values()) #print a list of the dictionary values

SecondDict = FirstDict.copy()  #copy your 1st dictionary ino a 2nd dictionary

SecondDict.pop('1')   #pop an item from the 2nd dictionary, 

print(SecondDict)  #and print the dictionary

SecondDict.clear()  #Remove all the elements from the 2nd dictionary
print(SecondDict)   #and print the result.
# Out:
# 7 elements in list.
# ['Ford', True, 'Cheesecake']
# [False, False, True, True, True]
# [False, False, True, True, True, 'Ford', True, 'Cheesecake']
# 5
# (0, 0, 0, 5, 5, 5, 10, 10, 10, 15, 15, 15, 20, 20, 20)
# (5, 10, 15, 20)
# 5 10 15 20
# (50,)
# (0, 0, 0, 5, 5, 5, 10, 10, 10, 15, 15, 15, 20, 20, 20, 5, 10, 15, 20)
# {'banana', 'grape', 'apple'}
# {'stringcheese', 'fork'}
# dict_keys(['1', '2', '3', '4', '5', '6', '7'])
# dict_values(['Blue', 'Jonathan', 'Orange', 'Red', 'Purple', 'Navy', {'stringcheese', 'fork'}])
# {'2': 'Jonathan', '3': 'Orange', '4': 'Red', '5': 'Purple', '6': 'Navy', '7': {'stringcheese', 'fork'}}
# {}
