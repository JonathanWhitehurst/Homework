# %%
#1. Create an if statement: 
    # if 'age' is greater than or equal to 25, print "Renting a car is more affordable", 
    # however if 'age' is less than 25, print "Renting a car is very expensive."
print("--- Task 1 ---")
age = int(input("Enter your age:"))
if age >= 25:
    print("Because you are at least 25, renting a car is more affordable.")
elif age < 25:
    print("Renting a car is very expensive, since you are not yet 25.")


#2. Create and chain an if-else  statement: 
    # If 'age' is greater than or equal to 25, print "Renting a car is more affordable." 
    # If 'age' is less than 25 but greater than or equal to 18, print "Renting a car is very expensive." 
    # Finally, if age is less than 18, print "You cannot legally rent a car."
print("\n--- Task 2 ---")
if age >= 25:
    print("Renting a car is more affordable.")
elif age < 25 and age >= 18:
    print("Renting a car is very expensive.")
elif age < 18:
    print("You cannot legally rent a car.")

#3. Loop over the following string to (1) count all the characters in the string and print out all the vowels -- 
    # "The quick brown fox jumps over the lazy dog."

import time  #Module to allow for sleep function

print("\n--- Task 3 ---")
foxDogSentence = "The quick brown fox jumps over the lazy dog."
#x = len(foxDogSentence)

vowelCount = 0
charCount = 0
print("Vowels in the following sentence will be printed below: 'The quick brown fox jumps over the lazy dog.'")
time.sleep(3)
for y in foxDogSentence:
    charCount+=1
    if y == "a" or y == "e" or y == "i" or y == "o" or y == "u" or y == "A" or y == "E" or y == "I" or y == "O" or y == "U":
        vowelCount+=1
        time.sleep(0.2)
        print(y)

print("There are a total of",vowelCount,"vowels in the sentence and the sentence is",charCount,"characters long.")

#4. Write a nested loop that 
    # prints out every piece of clothing from the `couture` list, 
    # in every fashionable color from the `panettone` set: 
    # couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] 
    # and panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

print("\n--- Task 4 ---")
print("Couture clothing and Panettone color combinations:")

couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] 
panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for clothing in couture:
    for color in panettone:
        print(clothing,color)

#5. Use range as a loop to calculate the sum of all the numbers from 1 to 100
print("\n--- Task 5 ---")
print("The sum of all numbers from 1 to 100 (inclusive):")
i=0
for z in range(1,101):
    i+=z
print(i)

#6. Print the second item in this fruits list.
    #["apple", "banana", "cherry"]
print("\n--- Task 6 ---")
fruits = ["apple", "banana", "cherry"]
b=fruits[1]
print("The second item in the list named fruits is", b,"\b.")

#7. Change the value from "apple" to "kiwi", in the fruits list.
    #["apple", "banana", "cherry"]
print("\n--- Task 7 ---")

fruits[0] = "kiwi"
print("Apple has been changed to kiwi in the fruits list.")
print(fruits)

#8. Use the append method to add "orange" to the fruits list.
    #["apple", "banana", "cherry"]
print("\n--- Task 8 ---")
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print("Orange added to end of list using the append method.")
print(fruits)

#9. Use the insert method to add "lemon" as the second item in the fruits list.
    #["apple", "banana", "cherry"]
print("\n--- Task 9 ---")

fruits = ["apple", "banana", "cherry"]
fruits.insert(1, "lemon")
print("Lemon has been added in the second position using the insert method.")
print(fruits)

#10. Use the remove method to remove "banana" from the fruits list.
    #["apple", "banana", "cherry"]

print("\n--- Task 10 ---")
fruits = ["apple", "banana", "cherry"]
fruits.remove("banana")
print("Banana has been removed from the fruits list.")
print(fruits)

#11. Use negative indexing to print the 3rd and 2nd to last items in the list.
    #["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("\n--- Task 11 ---")

fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("The third to last and second to last items in the fruits list are:")
print(fruits[-3],fruits[-2])

#12. Use a range of indexes to print the third, fourth, and fifth item in the list.
    #["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("\n--- Task 12 ---")

fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("The third to fifth items in the fruits list are:")
print(fruits[2:5])

#13. Use the correct syntax to print the number of items in the list.
    #["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("\n--- Task 13 ---")
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
allItemCount=len(fruits)
print("Fruits list updated:",fruits)
print("The total number of items in the fruits list is:",allItemCount)

#14. Use the correct syntax to sort this list in reverse order
   # ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print("\n--- Task 14 ---")

fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
fruits.sort(reverse=True)
print(fruits)

#15. Use the DateTime module to get Current Date and Time, and save it to a variable. 
    # Then extract just the month name form that variable.
print("\n--- Task 15 ---")
import datetime
currentTime=datetime.datetime.now()
print("The current month is",currentTime.strftime("%B"),"\b.")

'''16. Write a simple function that takes 2 parameters -- a  first name and a day name.
    - Set a default value for the day name of Sunday.
    - Have the function print out a greeting -- using the parameters -- that says something like "Hi first-name! Happy day-name!". Remember to use the variables in the greeting to replace first-name and day-name.  
    - Invoke this function with 2 variables.
    - Invoke this function with 1 variable only.'''
print("\n--- Task 16 ---")

def simple(firstName, dayName="Sunday"):
    print("Hi, "+firstName+"! Happy "+dayName+"!")


simple("Johan","Monday")              #function invoked with 2 variables
simple("Jared")                       #funcion invoked with 1 variable only

#17. Import NumPy and create an array with a shape of ... (2, 3, 2)
print("\n--- Task 17 ---")

import numpy
myArray=numpy.arange(12).reshape(2,3,2)
print("\n2x3x2 array.  Number of dimensions ...", myArray.ndim)

#Use NumPy `.linspace()` to create an array with 
# 6 linearly spaced values between 0 and 20
print("\n--- Task 18 ---")

spacedArray = numpy.linspace(0,20,6)
print(spacedArray)

#19. Make a Deep Copy of the above array you created.
print("\n--- Task 19 ---")
import copy
DCspacedArray = copy.deepcopy(spacedArray)
print(DCspacedArray, " Deep copy version of previous line.")

#20. What are 2 reasons we use NumPy over Python Lists?
print("\n--- Task 20 ---")
print("Two reasons we use NumPy over Python lists:")
print("1) NumPy arrays use LESS MEMORY than Python lists.")
print("2) NumPy arrays are FAST compared to Python lists.")
# Out:
# --- Task 1 ---
# Renting a car is very expensive, since you are not yet 25.
#
# --- Task 2 ---
# Renting a car is very expensive.
#
# --- Task 3 ---
# Vowels in the following sentence will be printed below: 'The quick brown fox jumps over the lazy dog.'
# e
# u
# i
# o
# o
# u
# o
# e
# e
# a
# o
# There are a total of 11 vowels in the sentence and the sentence is 44 characters long.
#
# --- Task 4 ---
# Couture clothing and Panettone color combinations:
# trousers cerise
# trousers aqua
# trousers burnt sienna
# trousers gunmetal blue
# trousers maple
# trousers Dark Sapphire
# trousers fuchsia
# trousers auburn
# blouse cerise
# blouse aqua
# blouse burnt sienna
# blouse gunmetal blue
# blouse maple
# blouse Dark Sapphire
# blouse fuchsia
# blouse auburn
# bandana cerise
# bandana aqua
# bandana burnt sienna
# bandana gunmetal blue
# bandana maple
# bandana Dark Sapphire
# bandana fuchsia
# bandana auburn
# cumber band cerise
# cumber band aqua
# cumber band burnt sienna
# ...
